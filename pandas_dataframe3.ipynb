# %%
import pandas as pd

train_data = pd.read_csv('./train.csv')

# %%
train_data.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
# pk로 사용할 인덱스 칼럼을 선택할 수 있다. 없으면 autoincrement로 자동 생성

train_data = pd.read_csv('./train.csv', index_col='PassengerId')
train_data.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
train_data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# 실제 필요한 칼럼만 특정해서 불러오는 것도 가능하다. 

train_data = pd.read_csv('./train.csv', index_col='PassengerId', usecols=['PassengerId','Survived', 'Pclass', 'Name'])
train_data.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...

# %% [markdown]
# # 원하는 칼럼만 선택하기

# %%
train_data = pd.read_csv('./train.csv')
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data['Name'].head()  # 원하는 칼럼만 조회하기
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
train_data[['Name', 'Survived']].head()  # 복수의 칼럼 조회하기
# Out:
#                                                 Name  Survived
# 0                            Braund, Mr. Owen Harris         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1
# 2                             Heikkinen, Miss. Laina         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1
# 4                           Allen, Mr. William Henry         0

# %% [markdown]
# # 원하는 로우만 조회하기

# %%
train_data[:4]    # 슬라이싱을 통해 로우를 가져올 수 있다.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
train_data.info()   # 총 로우 갯수를 알 수 있는 다양한 방법 중 하나. shape를 통해서도 행 열의 크기 조회 가능
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.index = range(1,892)

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
# 5            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1                            Braund, Mr. Owen Harris    male  22.0      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3                             Heikkinen, Miss. Laina  female  26.0      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0         A/5 21171   7.2500   NaN        S
# 2      0          PC 17599  71.2833   C85        C
# 3      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0            113803  53.1000  C123        S
# 5      0            373450   8.0500   NaN        S

# %%
train_data.loc[5]    # 슬라이싱 없이 특정 row 조회하기, series 형태로 리턴
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                  35
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 5, dtype: object

# %%
train_data.iloc[[5,890], [0,1]]  # 로우 칼럼 모두 조회 가능, iloc는 인덱스 순서를 바탕으로 동작 수행
# Out:
#      PassengerId  Survived
# 6              6         0
# 891          891         0

# %%
train_data.loc[[5,891], ['Name', 'Survived', 'Embarked']]  # 로우 칼럼 모두 조회 가능
# Out:
#                          Name  Survived Embarked
# 5    Allen, Mr. William Henry         0        S
# 891       Dooley, Mr. Patrick         0        Q
